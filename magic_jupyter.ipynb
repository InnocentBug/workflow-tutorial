# %%
import magic_python
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
fix, ax = plt.subplots()
x = np.linspace(0.1, 25.0)
for a in [0.2, 0.4, 0.6, 0.8]:
    ax.plot(x, magic_python.my_magic_function(x, a), label=f"$a={a}$")
ax.legend(loc="best")
